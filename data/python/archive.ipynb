# %% [markdown]
# # Archive below ...............................

# %%
frb
# Out:
#     match_number      date             home_team             away_team  \
# 3         129822  03-10-21                   VLI  Frederiksberg Volley
# 8         129830  10-10-21  Frederiksberg Volley         Hvidovre VK.2
# 10        129835  17-10-21  Frederiksberg Volley           Amager VK.2
# 14        129860  31-10-21  Frederiksberg Volley           Farum-Holte
# 19        129868  06-11-21            DTU Volley  Frederiksberg Volley
# ..           ...       ...                   ...                   ...
# 310       141089  02-11-24  Frederiksberg Volley             Team Køge
# 318       141094  16-11-24            DTU Volley  Frederiksberg Volley
# 320       141099  23-11-24  Frederiksberg Volley         Hvidovre VK.2
# 327       141104  01-12-24            Grøndal EV  Frederiksberg Volley
# 332       141108  08-12-24  Frederiksberg Volley     Gentofte Volley.2
#
#                                      stadium result     season   time  \
# ...

# %%
summary_2022_2023
# Out:
#                       home_games_played  away_games_played  \
# Amager VK.2                           9                  9
# DTU Volley                            9                  9
# Farum-Holte                           9                  9
# Frederiksberg Volley                  9                  9
# Gentofte Volley.2                     9                  9
# Grøndal EV                            9                  9
# Hvidovre VK.2                         9                  9
# KSV                                   9                  9
# VK Holbæk                             9                  9
# VLI                                   9                  9
#
#                       total_games_played  sets_won  sets_lost  games_won
# Amager VK.2                           18        49         23         15
# DTU Volley                            18        33         41          6
# Farum-Holte                           18        45         26         13
# ...

# %%
df_2022_2023
# Out:
#    match_number      date             home_team          away_team  \
# 0        134638  24-09-22             VK Holbæk         DTU Volley
# 1        134637  01-10-22  Frederiksberg Volley  Gentofte Volley.2
# 2        134640  02-10-22           Amager VK.2         Grøndal EV
# 3        134639  02-10-22                   VLI                KSV
# 4        134641  02-10-22           Farum-Holte      Hvidovre VK.2
# ..          ...       ...                   ...                ...
# 85       134723  01-04-23             VK Holbæk        Farum-Holte
# 86       134724  01-04-23            DTU Volley         Grøndal EV
# 87       134726  01-04-23  Frederiksberg Volley        Amager VK.2
# 88       134722  02-04-23     Gentofte Volley.2                VLI
# 89       134725  02-04-23         Hvidovre VK.2                KSV
#
#                                    stadium result     season   time  \
# 0         Bjergmarkshallen                  3 - 2  2022-2023  12:00
# ...
