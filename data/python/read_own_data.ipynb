# %%
import pandas as pd
import requests
import io


# Your CSV URL
csv_url = 'http://docs.google.com/spreadsheets/d/e/2PACX-1vRPsE2E-zRI8H2qKVpBFMXJDd0_TD4giPb4NN-3pZSnrP63gh2A2bcddtJLLg0zCLs0AbKW28TxrYw3/pub?gid=247177857&single=true&output=csv'


# Fetch the CSV content
response = requests.get(csv_url)
response.raise_for_status()  # Raise an error for HTTP issues

# Read the CSV into pandas
df = pd.read_csv(io.StringIO(response.text))

# %%
df
# Out:
#     match-id tournament    opponent   home-team   away-team        date  \
# 0     143034        cup    roedovre    roedovre         frb  22-09-2024
# 1     143643        cup  farumholte  farumholte         frb  20-10-2024
# 2     141063       1div    gentofte    gentofte         frb  29-09-2024
# 3     141067       1div        kv61         frb        kv61  06-10-2024
# 4     141074       1div      amager         frb      amager  13-10-2024
# 5     141078       1div         vli         vli         frb  27-10-2024
# 6     141089       1div   teamkoege         frb   teamkoege  02-11-2024
# 7     141094       1div         dtu         dtu         frb  16-11-2024
# 8     141099       1div    hvidovre         frb    hvidovre  23-11-2024
# 9     141104       1div    groendal    groendal         frb  01-12-2024
# 10    141108       1div    gentofte         frb    gentofte  08-12-2024
# 11    141119       1div      amager      amager         frb  12-01-2025
# 12    141123       1div         vli         frb         vli  18-01-2025
# 13    141139       1div         dtu         frb         dtu  25-01-2025
# 14    141084       1div  farumholte         frb  farumholte  22-02-2025
# 15    141112       1div        kv61        kv61         frb  08-03-2025
# 16    141134       1div   teamkoege   teamkoege         frb  14-03-2025
# 17    141149       1div    groendal         frb    groendal  23-03-2025
# 18    141144       1div    hvidovre    hvidovre         frb  29-03-2025
# 19    141129       1div  farumholte  farumholte         frb  06-04-2025
#
#     sets-won-frb frb-result  sets-won-opponenent     season frb-home-or-away  \
# 0            3.0        win                  0.0  2024-2025             away
# 1            0.0       lose                  3.0  2024-2025             away
# 2            2.0       lose                  3.0  2024-2025             away
# 3            3.0        win                  0.0  2024-2025             home
# 4            0.0       lose                  3.0  2024-2025             home
# 5            0.0       lose                  3.0  2024-2025             away
# 6            3.0        win                  0.0  2024-2025             home
# 7            3.0        win                  2.0  2024-2025             away
# 8            2.0       lose                  3.0  2024-2025             home
# 9            3.0        win                  0.0  2024-2025             away
# 10           3.0        win                  1.0  2024-2025             home
# 11           NaN        NaN                  NaN  2024-2025             away
# 12           NaN        NaN                  NaN  2024-2025             home
# 13           NaN        NaN                  NaN  2024-2025             home
# 14           NaN        NaN                  NaN  2024-2025             home
# 15           NaN        NaN                  NaN  2024-2025             away
# 16           NaN        NaN                  NaN  2024-2025             away
# 17           NaN        NaN                  NaN  2024-2025             home
# 18           NaN        NaN                  NaN  2024-2025             away
# 19           NaN        NaN                  NaN  2024-2025             away
#
#    match-played
# 0           yes
# 1           yes
# 2           yes
# 3           yes
# 4           yes
# 5           yes
# 6           yes
# 7           yes
# 8           yes
# 9           yes
# 10          yes
# 11           no
# 12           no
# 13           no
# 14           no
# 15           no
# 16           no
# 17           no
# 18           no
# 19           no

# %%
matches_played = df[df["match-played"] == "yes"]
frb_home_games = matches_played[matches_played["frb-home-or-away"] == "home"]

# Count the total games
total_games = len(frb_home_games)

# Count the games won
games_won = frb_home_games['frb-result'].str.lower().value_counts().get('win', 0)

# Calculate win percentage
win_percentage = (games_won / total_games) * 100


print(f"Home win ratio:", win_percentage,"%")
# Out:
# Home win ratio: 60.0 %

# %%
matches_played = df[df["match-played"] == "yes"]
frb_home_games = matches_played[matches_played["frb-home-or-away"] == "away"]

# Count the total games
total_games = len(frb_home_games)

# Count the games won
games_won = frb_home_games['frb-result'].str.lower().value_counts().get('win', 0)

# Calculate win percentage
win_percentage = (games_won / total_games) * 100


print(f"Away win ratio:", win_percentage,"%")
# Out:
# Away win ratio: 50.0 %

# %%
home_wins = df[df["frb-result"] == "win"]
home_wins
# Out:
#     match-id tournament   opponent home-team  away-team        date  \
# 0     143034        cup   roedovre  roedovre        frb  22-09-2024
# 3     141067       1div       kv61       frb       kv61  06-10-2024
# 6     141089       1div  teamkoege       frb  teamkoege  02-11-2024
# 7     141094       1div        dtu       dtu        frb  16-11-2024
# 9     141104       1div   groendal  groendal        frb  01-12-2024
# 10    141108       1div   gentofte       frb   gentofte  08-12-2024
#
#     sets-won-frb frb-result  sets-won-opponenent     season frb-home-or-away
# 0            3.0        win                  0.0  2024-2025             away
# 3            3.0        win                  0.0  2024-2025             home
# 6            3.0        win                  0.0  2024-2025             home
# 7            3.0        win                  2.0  2024-2025             away
# 9            3.0        win                  0.0  2024-2025             away
# 10           3.0        win                  1.0  2024-2025             home

# %%
def calculate_win_ratio(df, seasons, game_type):
    if 'all' not in seasons:
        df = df[df['season'].isin(seasons)]
    if game_type != 'all':
        df = df[df['frb-home-or-away'] == game_type]

    total_games = len(df)
    games_won = df['frb-result'].str.lower().value_counts().get('win', 0)
    return (games_won / total_games) * 100 if total_games > 0 else 0


# Calculate win ratio for all games across all seasons
overall_win_ratio = calculate_win_ratio(matches_played, ['all'], 'all')
print(f"Overall Win Ratio: {overall_win_ratio:.2f}%")

# Calculate win ratio for home games in 2022
home_win_ratio_2022 = calculate_win_ratio(matches_played, ['2024-2025'], 'home')
print(f"Home Win Ratio (24-25): {home_win_ratio_2022:.2f}%")

# Calculate win ratio for away games in 2023
away_win_ratio_2023 = calculate_win_ratio(matches_played, ['2024-2025'], 'away')
print(f"Away Win Ratio (24-25): {away_win_ratio_2023:.2f}%")
# Out:
# Overall Win Ratio: 54.55%
# Home Win Ratio (24-25): 60.00%
# Away Win Ratio (24-25): 50.00%

# %%
results = []
seasons = ['2022', '2023', 'all']
game_types = ['home', 'away', 'all']

for season in seasons:
    for game_type in game_types:
        win_ratio = calculate_win_ratio(df, [season], game_type)
        results.append({
            'season': season,
            'game_type': game_type,
            'win_ratio': win_ratio
        })

# Convert results to a DataFrame for easier handling
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#   season game_type  win_ratio
# 0   2022      home   0.000000
# 1   2022      away   0.000000
# 2   2022       all   0.000000
# 3   2023      home   0.000000
# 4   2023      away   0.000000
# 5   2023       all   0.000000
# 6    all      home  33.333333
# 7    all      away  27.272727
# 8    all       all  30.000000
